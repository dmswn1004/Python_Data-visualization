# %% [markdown]
# ## 공공 데이터 포탈 데이터 가져오기

# %%
import requests

url = 'http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty'
params ={'serviceKey' : 'I4L+4MoWrW0ZasxQ3TxTlDG36qDOPpsaipij0X7b4m/LwuvNmaiNTvSzLdGtFBeTQrIC3OiKjN4qbiuqFCQGZA==', 'returnType' : 'json', 'numOfRows' : '742', 'pageNo' : '1', 'stationName' : '종로구', 'dataTerm' : 'MONTH', 'ver' : '1.0' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'{"response":{"body":{"totalCount":739,"items":[{"so2Grade":"1","coFlag":null,"khaiValue":"62","so2Value":"0.003","coValue":"0.6","pm25Flag":null,"pm10Flag":null,"pm10Value":"23","o3Grade":"2","khaiGrade":"2","pm25Value":"7","no2Flag":null,"no2Grade":"1","o3Flag":null,"pm25Grade":"1","so2Flag":null,"dataTime":"2023-04-19 12:00","coGrade":"1","no2Value":"0.011","pm10Grade":"1","o3Value":"0.044"},{"so2Grade":"1","coFlag":null,"khaiValue":"58","so2Value":"0.005","coValue":"0.6","pm25Flag":null,"pm10Flag":null,"pm10Value":"24","o3Grade":"2","khaiGrade":"2","pm25Value":"5","no2Flag":null,"no2Grade":"1","o3Flag":null,"pm25Grade":"1","so2Flag":null,"dataTime":"2023-04-19 11:00","coGrade":"1","no2Value":"0.010","pm10Grade":"1","o3Value":"0.039"},{"so2Grade":"1","coFlag":null,"khaiValue":"54","so2Value":"0.003","coValue":"0.6","pm25Flag":null,"pm10Flag":null,"pm10Value":"22","o3Grade":"2","khaiGrade":"2","pm25Value":"7","no2Flag":null,"no2Grade":"1","o3Flag":null,"pm25Grade":"1","so2Flag":nu
# ...

# %%
import json
import pandas as pd

# %%
json_df = json.loads(response.content)
print(json_df)
# Out:
# {'response': {'body': {'totalCount': 739, 'items': [{'so2Grade': '1', 'coFlag': None, 'khaiValue': '62', 'so2Value': '0.003', 'coValue': '0.6', 'pm25Flag': None, 'pm10Flag': None, 'pm10Value': '23', 'o3Grade': '2', 'khaiGrade': '2', 'pm25Value': '7', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2023-04-19 12:00', 'coGrade': '1', 'no2Value': '0.011', 'pm10Grade': '1', 'o3Value': '0.044'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '58', 'so2Value': '0.005', 'coValue': '0.6', 'pm25Flag': None, 'pm10Flag': None, 'pm10Value': '24', 'o3Grade': '2', 'khaiGrade': '2', 'pm25Value': '5', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2023-04-19 11:00', 'coGrade': '1', 'no2Value': '0.010', 'pm10Grade': '1', 'o3Value': '0.039'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '54', 'so2Value': '0.003', 'coValue': '0.6', 'pm25Flag': None, 'pm10Flag': None, 'pm10Value': '22', 'o3Grade': '2',
# ...

# %%
type(json_df)
# Out:
# dict

# %%
data_items = json_df['response']['body']['items']
print(data_items)
# Out:
# [{'so2Grade': '1', 'coFlag': None, 'khaiValue': '62', 'so2Value': '0.003', 'coValue': '0.6', 'pm25Flag': None, 'pm10Flag': None, 'pm10Value': '23', 'o3Grade': '2', 'khaiGrade': '2', 'pm25Value': '7', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2023-04-19 12:00', 'coGrade': '1', 'no2Value': '0.011', 'pm10Grade': '1', 'o3Value': '0.044'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '58', 'so2Value': '0.005', 'coValue': '0.6', 'pm25Flag': None, 'pm10Flag': None, 'pm10Value': '24', 'o3Grade': '2', 'khaiGrade': '2', 'pm25Value': '5', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2023-04-19 11:00', 'coGrade': '1', 'no2Value': '0.010', 'pm10Grade': '1', 'o3Value': '0.039'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '54', 'so2Value': '0.003', 'coValue': '0.6', 'pm25Flag': None, 'pm10Flag': None, 'pm10Value': '22', 'o3Grade': '2', 'khaiGrade': '2', 'pm25Value': '7', 'no2Flag': Non
# ...

# %%
df = pd.json_normalize(data_items)
df
# Out:
#     so2Grade coFlag khaiValue so2Value coValue pm25Flag pm10Flag pm10Value  \
# 0          1   None        62    0.003     0.6     None     None        23
# 1          1   None        58    0.005     0.6     None     None        24
# 2          1   None        54    0.003     0.6     None     None        22
# 3          1   None        47    0.002     0.6     None     None        21
# 4          1   None        40    0.002     0.6     None     None        18
# ..       ...    ...       ...      ...     ...      ...      ...       ...
# 734        1   None       132    0.004     0.6     None     None        76
# 735        1   None       135    0.005     0.6     None     None        80
# 736        1   None       139    0.005     0.6     None     None        76
# 737        1   None       139    0.005     0.6     None     None        82
# 738        1   None       147    0.004     0.6     None     None        85
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 739 entries, 0 to 738
# Data columns (total 21 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   so2Grade   539 non-null    object
#  1   coFlag     4 non-null      object
#  2   khaiValue  739 non-null    object
#  3   so2Value   739 non-null    object
#  4   coValue    739 non-null    object
#  5   pm25Flag   0 non-null      object
#  6   pm10Flag   1 non-null      object
#  7   pm10Value  739 non-null    object
#  8   o3Grade    717 non-null    object
#  9   khaiGrade  711 non-null    object
#  10  pm25Value  739 non-null    object
#  11  no2Flag    4 non-null      object
#  12  no2Grade   735 non-null    object
#  13  o3Flag     22 non-null     object
#  14  pm25Grade  733 non-null    object
#  15  so2Flag    200 non-null    object
#  16  dataTime   739 non-null    object
#  17  coGrade    735 non-null    object
#  18  no2Value   739 non-null    object
# ...
